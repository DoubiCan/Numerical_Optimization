# %% [markdown]
# # 非线性共轭梯度方法:
# 试图将用于求解二次型最小值的共轭梯度方法用于普适非约束函数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# 这里提到说Linesearch可以保证$\alpha$一些比较好的性质
